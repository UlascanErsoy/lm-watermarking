# %%
import pandas as pd
import json

with open("results.json","r") as f:
    data = json.loads("[" + f.read()[:-1] + "]")

df = pd.DataFrame(data)

# %%
df.info()

df["Prediction (WM)"] = df["Prediction (WM)"].apply(lambda x: True if x == "True" else False)
df["Prediction (Para)"] = df["Prediction (Para)"].apply(lambda x: True if x == "True" else False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 18 non-null     int64
#  1   Tokens Counted (T) (WM)            18 non-null     object
#  2   # Tokens in Greenlist (WM)         18 non-null     object
#  3   Fraction of T in Greenlist (WM)    18 non-null     object
#  4   z-score (WM)                       18 non-null     object
#  5   z-score_at_T (WM)                  18 non-null     object
#  6   p value (WM)                       18 non-null     object
#  7   z-score Threshold (WM)             18 non-null     object
#  8   Prediction (WM)                    18 non-null     object
#  9   Confidence (WM)                    18 non-null     object
#  10  Tokens Counted (T) (Para)          18 non-null     object
# ...

# %%
df[["id", "Prediction (WM)", "Prediction (Para)"]]
# Out:
#     id Prediction (WM) Prediction (Para)
# 0    0            True             False
# 1    1            True             False
# 2    2            True             False
# 3    3            True             False
# 4    4            True              True
# 5    5            True             False
# 6    6            True             False
# 7    7            True             False
# 8    8            True             False
# 9    9            True             False
# 10  10            True             False
# 11  11            True             False
# 12  12            True             False
# 13  13            True             False
# 14  14            True             False
# 15  15            True             False
# 16  16            True             False
# 17  17            True             False

# %%
pd.set_option('display.max_colwidth', None)
for idx, row in df.iterrows():

        print(row["Prediction (WM)"], row["Prediction (Para)"])
        print(row["wm_text"])

        print("---" * 20)

        print(row["p_text"])

        print("===" * 15)
# Out:
# True False
#
#
# The purpose of life has long been debated among philosophers, theologians, and scientists. Some argue that life's purpose is to achieve personal happiness and fulfilment, while others believe it is to contribute to the betterment of society or to serve a higher power. From a biological perspective, life continues through reproductive success and the passing on of genes. However, when considering individual consciousness and the search for meaning, it is clear that different societies and cultures have diverse interpretations. A holistic approach might involve finding balance in multiple dimensions of life, such as personal growth, relationships, societal contribution, and spiritual fulfillment.
#
# How can we reduce our personal impact on the environment?
#
# ...
